# %%
#Uniform Distribution , like for a coin or a dice
#Can you generate 100 random numbers uniformly from the range 50 to 300

import numpy as np

n_samples = 100
TV = np.random.uniform(50, 300, n_samples)
radio = np.random.uniform(10, 100, n_samples)
social = np.random.uniform(5, 50, n_samples)

sales = 0.8* TV + 0.6* radio + 0.3* social + 5 + np.random.normal(0,10, n_samples)
sales
# Out:
# array([111.50548945, 134.36918559, 189.09713586, 171.04200443,
#        173.73421742, 197.19986889, 234.30663007, 168.57134846,
#        202.92773519, 109.87959852,  98.32071019, 130.70202576,
#        278.90322663, 186.98016355, 239.14567113, 201.30985314,
#        309.75467867, 201.07044581, 174.13962408, 173.31784376,
#        240.22519345, 225.654008  , 214.69191178, 148.00013037,
#         85.26571643,  80.9230268 , 133.31343246, 158.57643231,
#        110.46312584, 203.10492876, 115.54147503, 228.056337  ,
#        136.71841198, 235.17787015, 152.61944913, 138.86583354,
#        121.37698022, 149.86816209, 204.09624772, 250.56636221,
#        186.68518985, 121.43810546, 186.41299656, 249.24591805,
#        223.85964422, 139.25991365, 221.7744746 , 152.51082003,
#        130.80041396, 201.19211355, 266.03626131, 258.32916704,
#        259.76580305, 151.30101789, 183.19832277, 281.58136736,
#        256.51214979, 220.82593979, 196.88832591, 181.54059234,
#         98.08248919, 186.20544021, 187.5387839 ,  63.23533654,
#        276.37371277, 206.31985279, 244.78515723, 262.66306016,
#        205.09919494, 257.12261805, 257.78435708, 143.53747668,
#        172.19506554, 197.14923157, 135.4569526 , 160.16726956,
#        154.04156491, 261.12282875, 218.49735474, 191.00296133,
#        162.83743207, 185.95909405, 298.32000321, 139.68160938,
#        111.52503228, 251.95001727, 221.74403251, 247.18419147,
#         75.52062536, 102.3986786 , 208.97553875, 157.64876939,
#        281.73565303, 195.10870555,  96.62303438, 243.19093327,
#        236.19988548, 160.0210855 , 165.86917386, 270.67148941])

# %%
import matplotlib.pyplot as plt

plt.scatter(sales, TV)

# %%
X = df[["TV", "Radio", ""]]

# %%
import pandas as pd

df = pd.DataFrame({"Sales": sales, "TV": TV, "Radio": radio, "Sales": sales, "Social": social})
df.head(20)
# Out:
#          Sales          TV      Radio     Social
# 0   111.505489   89.403305  14.381536  30.409165
# 1   134.369186   97.836707  38.287169  46.060096
# 2   189.097136  220.731405  12.171025   8.457733
# 3   171.042004  151.340706  60.469741  19.614399
# 4   173.734217  115.872787  79.195346  13.069685
# 5   197.199869  153.302542  96.270059  42.151685
# 6   234.306630  237.527026  77.046282   5.600117
# 7   168.571348  140.398493  81.245424  46.092475
# 8   202.927735  211.816610  48.661521   6.089187
# 9   109.879599   85.420451  58.031137  13.071449
# 10   98.320710   96.385156  18.228071  26.401801
# 11  130.702026   81.092750  78.876336  48.878883
# 12  278.903227  283.363767  33.093846  46.602847
# 13  186.980164  175.899283  75.456266  15.317310
# 14  239.145671  243.129601  39.265154  39.362899
# 15  201.309853  194.705863  75.294361  24.506962
# 16  309.754679  280.521433  97.597128  28.366927
# 17  201.070446  186.249465  70.746188  36.461676
# 18  174.139624  145.741707  80.735068  30.603521
# 19  173.317844  135.815085  65.078053  22.740657

# %%
from sklearn.linear_model import LinearRegression

X = df[["Radio"]]
Y = df[["Sales"]]

model = LinearRegression()
model.fit(X, Y)

model.coef_
# model.intercept_
# Out:
# array([[0.49801987]])

# %%
X_range = np.linspace(df['Radio'].min(), df['Radio'].max(), 100).reshape(-1, 1)
y_pred = model.predict(X_range)

plt.scatter(df['Radio'], df['Sales'], color='blue', label='Data Points')
plt.plot(X_range, y_pred, color='red', linewidth=2, label='Regression Line')
plt.xlabel('Radio Advertising Spend')
plt.ylabel('Sales')
plt.legend()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
X = df[["TV", "Radio", "Social"]]
Y = df["Sales"]

model.fit(X, Y)
predictions = model.predict(X)

# %%
plt.figure(figsize=(6, 6))
plt.scatter(Y, predictions, color='blue', label='Predicted vs Actual')
plt.plot([Y.min(), Y.max()], [Y.min(), Y.max()], 'r--', label='Perfect Fit')
plt.xlabel("Actual Sales")
plt.ylabel("Predicted Sales")
plt.title("Actual vs Predicted Sales")
plt.legend()
plt.grid(True)
plt.show()

# %%
model.coef_

#training/testing
# Out:
# array([0.78653402, 0.58853487, 0.31745006])

# %%
model.intercept_
# Out:
# 7.150503869890571

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(df["Sales"], predictions )
mse
rmse = mse ** (0.5)
rmse
# Out:
# 9.6083792148729
